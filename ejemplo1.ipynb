# %% [markdown]
# <a href="https://colab.research.google.com/github/camilor96/se-alesimg/blob/master/ejemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Librerias necesarias para importar**

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread ('/content/drive/My Drive/Universidad/Señales_de_Imagen_2019/duke.jpg' , cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1103x1000 at 0x7FED38F388D0>

# %% [markdown]
# ### **Como entrar a una carpeta para traer una imagen y modificarle el tamaño**

# %% [markdown]
# ### **Opcion 1**

# %%
# !pwd
# !ls
# %cd /content/drive/My Drive/Universidad/Señales_de_Imagen_2019/
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('duke.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300), int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/Universidad/Señales_de_Imagen_2019
# duke.jpg
# /content/drive/My Drive/Universidad/Señales_de_Imagen_2019
# /content/drive/My Drive/Universidad/Señales_de_Imagen_2019
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FED38F569B0>

# %% [markdown]
# ### **Opcion 2**

# %%
import os

path = '/content/drive/My Drive/Universidad/Señales_de_Imagen_2019/'
os.chdir(path)
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('duke.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300), int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/Universidad/Señales_de_Imagen_2019
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FED38F5EC18>

# %% [markdown]
# ### **Cargar imagen original y visualizar con matplotlib**

# %%
img_BGR=cv2.imread('/content/drive/My Drive/Universidad/Señales_de_Imagen_2019/duke.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# ### **CAMBIAR TAMAÑOS DE LA IMAGEN**

# %%
print(img.shape)
res = cv2.resize(img, None,fx=10, fy=10, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 300, 3)
# (3000, 3000, 3)

# %%
print(img.shape)
res = cv2.resize(img, None,fx=.1, fy=.1, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 300, 3)
# (30, 30, 3)

# %% [markdown]
# ### ** Remover numeracion de los ejes**

# %%
plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## ** Cambiar de BGR a RGB**

# %%
img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## **Convertir a escala de grices **

# %%
img_GRAY=cv2.cvtColor(img_RGB,cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img_GRAY=cv2.cvtColor(img_RGB,cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ### **Crear y usar metodos para mostrar las imagenes **

# %%
def display(a, b, title1 = "Original", title2= "Editado"):
    plt.figure(figsize=(14,14))
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
    
    
def display_one(a, title1= "Original"):
    plt.imshow(a), plt.title(title1)
    plt.show()
    

display_one(img_BGR)



display(img_BGR, img_GRAY, "BGR", "GRAY")

# %%
def display4(a, b, c, d, title1 = "Original", title2= "Editado", title3= "Editado", title4= "Editado"):
    plt.figure(figsize=(14,14))
    plt.subplot(221), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(222), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(223), plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(224), plt.imshow(d, cmap="gray"), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
display4(img_BGR,img_RGB,img_GRAY,img_GRAY, "BGR", "RGB", "GRAY", "GRAY2")

# %% [markdown]
# ### ** Caracteristicas de una Imagen**

# %%
img_GRAY.shape
# Out:
# (1000, 1103)

# %%
img_RGB.shape
# Out:
# (1000, 1103, 3)

# %%
def estadisticas(img):
  
  img_size=img.shape
  
  if len(img_size)>2:
    print("image chanels", img_size[2])
    
  else:
    print("image chanels", 1)
    
  print("image W",img_size[1])
  print("image H",img_size[0])
  print("min value",img.min())
  print("max value",img.max())
  print("prom",img.mean())
  print("type",img.dtype)
  
estadisticas(img_BGR)
estadisticas(img_GRAY)
# Out:
# image chanels 3
# image W 1103
# image H 1000
# min value 0
# max value 255
# prom 193.90849440918706
# type uint8
# image chanels 1
# image W 1103
# image H 1000
# min value 0
# max value 255
# prom 194.2448993653672
# type uint8
